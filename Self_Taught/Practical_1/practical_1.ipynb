# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
ls
# Out:
# 2.2 cost_revenue_dirty.csv  practical_1.ipynb
# 3.2 cost_revenue_clean.csv

# %%
data = pd.read_csv('2.2 cost_revenue_dirty.csv')

# %%
data.head(10)
# Out:
#    Rank Release Date                     Movie Title Production Budget ($)  \
# 0  5293     8/2/1915           The Birth of a Nation              $110,000
# 1  5140     5/9/1916                     Intolerance              $385,907
# 2  5230   12/24/1916    20,000 Leagues Under the Sea              $200,000
# 3  5299    9/17/1920  Over the Hill to the Poorhouse              $100,000
# 4  5222     1/1/1925                  The Big Parade              $245,000
# 5  4250   12/30/1925                         Ben-Hur            $3,900,000
# 6  4630    12/8/1927                           Wings            $2,000,000
# 7  5141     1/2/1929             The Broadway Melody              $379,000
# 8  4240     1/1/1930                   Hell's Angels            $4,000,000
# 9  5043   12/31/1931                       Mata Hari              $558,000
#
#   Worldwide Gross ($) Domestic Gross ($)
# 0         $11,000,000        $10,000,000
# 1                  $0                 $0
# ...

# %%
### This code will help us to get the indexes of all the records where  Worldwide Gross ($) = 0

index = np.where(data['Worldwide Gross ($)'] =='$0')

# %%
index
# Out:
# (array([   1,    6,    8,   17,   27,   50,   66,   75,   78,  140,  153,
#          168,  177,  198,  228,  401,  429,  474,  585,  837, 1634, 1666,
#         1745, 1866, 2043, 2113, 2154, 2156, 2244, 2358, 2359, 2360, 2410,
#         2513, 2563, 2580, 2581, 2587, 2631, 2675, 2702, 2728, 2748, 2837,
#         2847, 2850, 2873, 2930, 3003, 3011, 3025, 3044, 3050, 3053, 3054,
#         3055, 3056, 3068, 3176, 3195, 3209, 3238, 3244, 3262, 3287, 3300,
#         3306, 3309, 3310, 3312, 3313, 3317, 3338, 3384, 3394, 3410, 3412,
#         3413, 3421, 3480, 3483, 3523, 3541, 3542, 3543, 3544, 3545, 3546,
#         3548, 3549, 3550, 3553, 3562, 3576, 3607, 3639, 3644, 3813, 3814,
#         3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3828, 3854, 3858,
#         3859, 3918, 3978, 3998, 4046, 4066, 4067, 4068, 4070, 4071, 4109,
#         4112, 4114, 4121, 4123, 4129, 4130, 4138, 4163, 4169, 4189, 4195,
#         4218, 4226, 4229, 4236, 4283, 4297, 4298, 4299, 4300, 4301, 4302,
# ...

# %%
data = data.drop(data.index[index])

# %%
data.reset_index(drop=True)
# Out:
#       Rank Release Date                       Movie Title  \
# 0     5293     8/2/1915             The Birth of a Nation
# 1     5230   12/24/1916      20,000 Leagues Under the Sea
# 2     5299    9/17/1920    Over the Hill to the Poorhouse
# 3     5222     1/1/1925                    The Big Parade
# 4     4250   12/30/1925                           Ben-Hur
# ...    ...          ...                               ...
# 5029   914    10/2/2017               Fifty Shades Darker
# 5030  1295    10/2/2017            John Wick: Chapter Two
# 5031    70    10/3/2017                Kong: Skull Island
# 5032    94    12/5/2017  King Arthur: Legend of the Sword
# 5033  1254    12/5/2017                          Snatched
#
#      Production Budget ($) Worldwide Gross ($) Domestic Gross ($)
# 0                 $110,000         $11,000,000        $10,000,000
# 1                 $200,000          $8,000,000         $8,000,000
# 2                 $100,000          $3,000,000         $3,000,000
# ...

# %%
data[data['Domestic Gross ($)'] =='$0']
# Out:
#       Rank Release Date              Movie Title Production Budget ($)  \
# 71    4310    2/16/1956                 Carousel            $3,380,000
# 1579  5087    2/11/2001  Everything Put Together              $500,000
# 1744  3695   12/31/2001                 The Hole            $7,500,000
# 2155  4236   12/31/2003                  Nothing            $4,000,000
# 2203  2513    3/31/2004                The Touch           $20,000,000
# ...    ...          ...                      ...                   ...
# 5340  1506    4/14/2017      Queen of the Desert           $36,000,000
# 5348  2225     5/5/2017        Chāi dàn zhuānjiā           $23,000,000
# 5360  4832     7/3/2017                Departure            $1,100,000
# 5372  1856    8/25/2017                Ballerina           $30,000,000
# 5374  4237    8/25/2017     Polina danser sa vie            $4,000,000
#
#      Worldwide Gross ($) Domestic Gross ($)
# 71                $3,220                 $0
# ...

# %%
### This code will help us to get the indexes of all the records where  Domestic Gross ($) = 0

index1 = np.where(data['Domestic Gross ($)'] =='$0') 
data = data.drop(data.index[index1])
data.reset_index(drop=True)
# Out:
#       Rank Release Date                       Movie Title  \
# 0     5293     8/2/1915             The Birth of a Nation
# 1     5230   12/24/1916      20,000 Leagues Under the Sea
# 2     5299    9/17/1920    Over the Hill to the Poorhouse
# 3     5222     1/1/1925                    The Big Parade
# 4     4250   12/30/1925                           Ben-Hur
# ...    ...          ...                               ...
# 4874   914    10/2/2017               Fifty Shades Darker
# 4875  1295    10/2/2017            John Wick: Chapter Two
# 4876    70    10/3/2017                Kong: Skull Island
# 4877    94    12/5/2017  King Arthur: Legend of the Sword
# 4878  1254    12/5/2017                          Snatched
#
#      Production Budget ($) Worldwide Gross ($) Domestic Gross ($)
# 0                 $110,000         $11,000,000        $10,000,000
# 1                 $200,000          $8,000,000         $8,000,000
# 2                 $100,000          $3,000,000         $3,000,000
# ...

# %%
data[data['Domestic Gross ($)'] =='$0']
# Out:
# Empty DataFrame
# Columns: [Rank, Release Date, Movie Title, Production Budget ($), Worldwide Gross ($), Domestic Gross ($)]
# Index: []

# %%
 ## We  have remove all the records having Domestic Gross ($) = $0 and Worldwide Gross ($) = $0

# %%
data.shape
# Out:
# (4879, 6)

# %%
data1 = data[['Worldwide Gross ($)','Production Budget ($)']]

# %%
data1
# Out:
#      Worldwide Gross ($) Production Budget ($)
# 0            $11,000,000              $110,000
# 2             $8,000,000              $200,000
# 3             $3,000,000              $100,000
# 4            $22,000,000              $245,000
# 5             $9,000,000            $3,900,000
# ...                  ...                   ...
# 5378        $376,856,949           $55,000,000
# 5379        $166,893,990           $40,000,000
# 5380        $561,137,727          $185,000,000
# 5381        $140,012,608          $175,000,000
# 5382         $57,850,343           $42,000,000
#
# [4879 rows x 2 columns]

# %%
var1 = []
for x in data1['Worldwide Gross ($)']:
    var1.append(x.replace('$','').replace(',',''))

# %%
var2 = []
for x in data1['Production Budget ($)']:
    var2.append(x.replace('$','').replace(',',''))

# %%
## Updating the new values

data1['Worldwide Gross ($)'] = var1
data1['Production Budget ($)'] = var2

# %%
data1
# Out:
#      Worldwide Gross ($) Production Budget ($)
# 0               11000000                110000
# 2                8000000                200000
# 3                3000000                100000
# 4               22000000                245000
# 5                9000000               3900000
# ...                  ...                   ...
# 5378           376856949              55000000
# 5379           166893990              40000000
# 5380           561137727             185000000
# 5381           140012608             175000000
# 5382            57850343              42000000
#
# [4879 rows x 2 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4879 entries, 0 to 5382
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Worldwide Gross ($)    4879 non-null   object
#  1   Production Budget ($)  4879 non-null   object
# dtypes: object(2)
# memory usage: 114.4+ KB

# %%
## style.format('${0:,.2f}')

# %%
data1['Worldwide Gross ($)'] = data1['Worldwide Gross ($)'].astype(str).astype(int)

# %%
data1['Production Budget ($)'] = data1['Production Budget ($)'].astype(str).astype(int)

# %%
data1
# Out:
#       Worldwide Gross ($)  Production Budget ($)
# 0                11000000                 110000
# 2                 8000000                 200000
# 3                 3000000                 100000
# 4                22000000                 245000
# 5                 9000000                3900000
# ...                   ...                    ...
# 5378            376856949               55000000
# 5379            166893990               40000000
# 5380            561137727              185000000
# 5381            140012608              175000000
# 5382             57850343               42000000
#
# [4879 rows x 2 columns]

# %% [raw]
# df['C'] = df['C'].apply(lambda x: f"${x/1000:.1f}k")
# If you want to use this method on all columns, you can replace apply with applymap

# %%
## data1['Worldwide Gross ($)'].apply(lambda x:f"{x/1000:2.f}")

# %%
new_data = data1.applymap(lambda x: f"{x/10:.2f}")

# %%
new_data
# Out:
#      Worldwide Gross ($) Production Budget ($)
# 0             1100000.00              11000.00
# 2              800000.00              20000.00
# 3              300000.00              10000.00
# 4             2200000.00              24500.00
# 5              900000.00             390000.00
# ...                  ...                   ...
# 5378         37685694.90            5500000.00
# 5379         16689399.00            4000000.00
# 5380         56113772.70           18500000.00
# 5381         14001260.80           17500000.00
# 5382          5785034.30            4200000.00
#
# [4879 rows x 2 columns]

# %% [raw]
# def clean_currency(x):
#     """ If the value is a string, then remove currency symbol and delimiters
#     otherwise, the value is numeric and can be converted
#     """
#     if isinstance(x, str):
#         return(x.replace('$', '').replace(',', ''))
#     return(x)

# %% [raw]
# df['Sales'] = df['Sales'].apply(clean_currency).astype('float')
# df['Sales_Type'] = df['Sales'].apply(lambda x: type(x).__name__)

# %% [markdown]
# ### rename the columns

# %%
Production_budget_us =
Worldwide_gross_us =

# %%
new_data1 = new_data.rename(columns={'Production Budget ($)':'Production_budget_us','Worldwide Gross ($)':'Worldwide_gross_us'},inplace=False)

# %%
new_data1
# Out:
#      Worldwide_gross_us Production_budget_us
# 0            1100000.00             11000.00
# 2             800000.00             20000.00
# 3             300000.00             10000.00
# 4            2200000.00             24500.00
# 5             900000.00            390000.00
# ...                 ...                  ...
# 5378        37685694.90           5500000.00
# 5379        16689399.00           4000000.00
# 5380        56113772.70          18500000.00
# 5381        14001260.80          17500000.00
# 5382         5785034.30           4200000.00
#
# [4879 rows x 2 columns]

# %%
## way to shift the columns name
t1 = new_data1['Worldwide_gross_us']
t2 = new_data1['Production_budget_us']

# %%
New_data = pd.concat([t2,t1],axis=1)

# %%
New_data
# Out:
#      Production_budget_us Worldwide_gross_us
# 0                11000.00         1100000.00
# 2                20000.00          800000.00
# 3                10000.00          300000.00
# 4                24500.00         2200000.00
# 5               390000.00          900000.00
# ...                   ...                ...
# 5378           5500000.00        37685694.90
# 5379           4000000.00        16689399.00
# 5380          18500000.00        56113772.70
# 5381          17500000.00        14001260.80
# 5382           4200000.00         5785034.30
#
# [4879 rows x 2 columns]

# %%
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4879 entries, 0 to 5382
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Production_budget_us  4879 non-null   object
#  1   Worldwide_gross_us    4879 non-null   object
# dtypes: object(2)
# memory usage: 114.4+ KB

# %%
var1 = []
for x in New_data['Production_budget_us']:
    var1.append(x.replace('.',''))

# %%
var2 = []
for x in New_data['Worldwide_gross_us']:
    var2.append(x.replace('.',''))

# %%
New_data['Production_budget_us'] = New_data['Production_budget_us'].astype(str).astype(float).astype(int)
New_data['Worldwide_gross_us'] = New_data['Worldwide_gross_us'].astype(str).astype(float).astype(int)

# %%
New_data
# Out:
#       Production_budget_us  Worldwide_gross_us
# 0                    11000             1100000
# 2                    20000              800000
# 3                    10000              300000
# 4                    24500             2200000
# 5                   390000              900000
# ...                    ...                 ...
# 5378               5500000            37685694
# 5379               4000000            16689399
# 5380              18500000            56113772
# 5381              17500000            14001260
# 5382               4200000             5785034
#
# [4879 rows x 2 columns]
